# %% [markdown]
# Box-Cox and Yeo-Johnson transformations are techniques used in statistics to stabilize variance and/or make data more normally distributed. Both are used primarily in cases where the data violates assumptions of normality or homogeneity of variance, which are often required by many statistical methods like linear regression.

# %% [markdown]
# # Box-Cox transformation:

# %% [markdown]
# The Box-Cox transformation is a power transformation that aims to stabilize the variance of a dataset and make it more normally distributed. It is defined by the formula:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The parameter λ can be any real number, and its value is usually determined through maximum likelihood estimation. The transformation is then applied using the chosen λ value.
# The Box-Cox transformation is not applicable if the data contains non-positive values since it involves taking logarithms or roots.

# %% [markdown]
# # Yeo-Johnson Transformation:

# %% [markdown]
# The Yeo-Johnson transformation is an extension of the Box-Cox transformation that addresses its limitation of only being applicable to strictly positive data. It can handle both positive and negative values.
# The Yeo-Johnson transformation is defined by the formula:
# ![image.png](attachment:image.png)

# %% [markdown]
# where
# y is the original data, and
# λ is the transformation parameter.

# %% [markdown]
# Similar to the Box-Cox transformation, the parameter λ can be estimated via maximum likelihood estimation.
#
# The Yeo-Johnson transformation is more flexible as it can handle a wider range of data types.
